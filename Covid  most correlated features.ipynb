# %%
import pandas as pd
data = pd.read_csv("owid-covid-data.csv")

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
data = pd.read_csv("owid-covid-data.csv")
X = data.iloc[:,0:20]
corrmat = data.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,20))

#plot heatmap
g=sns.heatmap(data[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
cor_target = abs(corrmat["positive_rate"])
relevant_features = cor_target[cor_target>0.3]
relevant_features
# Out:
# new_cases_per_million              0.483754
# new_cases_smoothed_per_million     0.511917
# new_deaths_per_million             0.416131
# new_deaths_smoothed_per_million    0.446936
# positive_rate                      1.000000
# stringency_index                   0.350236
# median_age                         0.312035
# aged_65_older                      0.315268
# aged_70_older                      0.311214
# Name: positive_rate, dtype: float64
